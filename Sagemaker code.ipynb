# %%
# %%time

import boto3
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()
print(role)

region = boto3.Session().region_name

s3_client = boto3.client("s3")

sess = sagemaker.Session()
data_bucket_name = 'thesis-bucket-distraction'
dataset_name = 'Distraction-Driver'
# Out:
# arn:aws:iam::957922590568:role/Sagemaker_full_access
# CPU times: user 886 ms, sys: 167 ms, total: 1.05 s
# Wall time: 30.4 s

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
training_image = sagemaker.image_uris.retrieve("image-classification", sess.boto_region_name)
# Out:
# 813361260812.dkr.ecr.eu-central-1.amazonaws.com/image-classification:1

# %%
base_dir='/tmp'
# %env BASE_DIR = $base_dir
# %env S3_DATA_BUCKET_NAME = $data_bucket_name
# %env DATASET_NAME = $dataset_name 

import sys,os

suffix='/mxnet/tools/im2rec.py'
im2rec = list(filter((lambda x: os.path.isfile(x+suffix)), sys.path))[0]+suffix
# %env IM2REC = $im2rec

# !aws s3 sync s3://$S3_DATA_BUCKET_NAME/$DATASET_NAME $BASE_DIR/$DATASET_NAME --quiet
# Out:
# env: BASE_DIR=/tmp
# env: S3_DATA_BUCKET_NAME=thesis-bucket-distraction
# env: DATASET_NAME=Distraction-Driver
# env: IM2REC=/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/mxnet/tools/im2rec.py

# %%
# %%bash
#
# cd $BASE_DIR
# rm *.rec
# rm *.lst
#
# echo "Creating LST files"
#
# python $IM2REC --list --recursive --pass-through --test-ratio=0.3 --train-ratio=0.7 $DATASET_NAME $DATASET_NAME > ${DATASET_NAME}_classes
#
# echo "Label classes:"
# cat ${DATASET_NAME}_classes
#
# echo "Creating RecordIO files"
# python $IM2REC --num-thread=4 ${DATASET_NAME}_train.lst $DATASET_NAME
# python $IM2REC --num-thread=4 ${DATASET_NAME}_test.lst $DATASET_NAME
# ls -lh *.rec
# Out:
# Creating LST files
# Label classes:
# drinking 0
# hair_and_makeup 1
# operating_the_radio 2
# reaching_behind 3
# safe_driving 4
# talking_left_hand 5
# talking_right_hand 6
# talking_to_passenger 7
# texting_left_hand 8
# texting_right_hand 9
# Creating RecordIO files
# Creating .rec file from /tmp/Distraction-Driver_train.lst in /tmp
# time: 0.6080989837646484  count: 0
# time: 4.950589418411255  count: 1000
# time: 5.031804800033569  count: 2000
# time: 4.985249042510986  count: 3000
# time: 4.970013618469238  count: 4000
# time: 4.880450963973999  count: 5000
# time: 5.009275197982788  count: 6000
# time: 4.96434211730957  count: 7000
# time: 4.834452390670776  count: 8000
# time: 4.961760997772217  count: 9000
# time: 4.950659275054932  count: 10000
# time: 4.961684226989746  count: 11000
# time: 4.970326900482178  count: 12000
# time: 4.8817832469940186  count: 13000
# time: 5.015281677246094  count: 14000
# time: 4.881587028503418  count: 15000
# Creating .rec file from /tmp/Distraction-Driver_test.lst in /tmp
# time: 0.03490614891052246  count: 0
# time: 10.19983696937561  count: 1000
# time: 4.97126030921936  count: 2000
# time: 4.924118995666504  count: 3000
# time: 5.1402060985565186  count: 4000
# time: 12.232492685317993  count: 5000
# time: 5.669327259063721  count: 6000
# -rw-rw-r-- 1 ec2-user ec2-user 508M Feb  7 22:12 Distraction-Driver_test.rec
# -rw-rw-r-- 1 ec2-user ec2-user 1.2G Feb  7 22:11 Distraction-Driver_train.rec
# rm: cannot remove ‘*.rec’: No such file or directory
# rm: cannot remove ‘*.lst’: No such file or directory

# %%
bucket = sess.default_bucket()
s3train_path = 's3://{}/{}/train/'.format(bucket, dataset_name)
s3validation_path = 's3://{}/{}/validation/'.format(bucket, dataset_name)

# !aws s3 rm s3://{bucket}/{dataset_name}/train --recursive
# !aws s3 rm s3://{bucket}/{dataset_name}/validation --recursive
    
# !aws s3 cp /tmp/{dataset_name}_train.rec $s3train_path
# !aws s3 cp /tmp/{dataset_name}_test.rec $s3validation_path
# Out:
# delete: s3://sagemaker-eu-central-1-957922590568/Distraction-Driver/train/Distraction-Driver_train.rec
# delete: s3://sagemaker-eu-central-1-957922590568/Distraction-Driver/validation/Distraction-Driver_test.rec
# upload: ../../../tmp/Distraction-Driver_train.rec to s3://sagemaker-eu-central-1-957922590568/Distraction-Driver/train/Distraction-Driver_train.rec
# upload: ../../../tmp/Distraction-Driver_test.rec to s3://sagemaker-eu-central-1-957922590568/Distraction-Driver/validation/Distraction-Driver_test.rec

# %%
train_data = sagemaker.inputs.TrainingInput(
    s3train_path,
    distribution='FullyReplicated',
    content_type='application/x-recordio',
    s3_data_type='S3Prefix'
)

validation_data = sagemaker.inputs.TrainingInput(
    s3validation_path,
    distribution='FullyReplicated',
    content_type='application/x-recordio',
    s3_data_type='S3Prefix'
)

data_channels = {'train': train_data, 'validation': validation_data}

# %%
s3_output_location = 's3://{}/{}/output'.format(bucket, dataset_name)
image_classifier = sagemaker.estimator.Estimator(
    training_image,
    role,
    instance_count=2, 
    instance_type="ml.p2.xlarge",
    volume_size=50, 
    max_run=360000,
    input_mode="File",
    output_path=s3_output_location,
    sagemaker_session = sess
)

# %%
num_classes = ! ls -l {base_dir}/{dataset_name} | wc -l
num_classes = int(num_classes[0]) - 1

num_training_samples = !cat {base_dir}/{dataset_name}_train.lst | wc -l
num_training_samples = int(num_training_samples[0])

image_classifier.set_hyperparameters(
    num_layers=18, 
    use_pretrained_model=1,
    image_shape="3,480,640",
    num_classes=num_classes,
    num_training_samples=num_training_samples,
    early_stopping="True",
    early_stopping_tolerance=0.05, 
    mini_batch_size=128, 
    epochs=8, 
    learning_rate=0.01,
    precision_dtype="float16" 
)

# %%
# %%time
import time
now = str(int(time.time()))
training_job_name = 'IC-' + dataset_name.replace('_', '-') + '-' + now
image_classifier.fit(inputs=data_channels, job_name=training_job_name, logs=True)
job = image_classifier.latest_training_job
model_path = f"{base_dir}/{job.name}"
# Out:
# 2022-02-07 22:12:25 Starting - Starting the training job...
# 2022-02-07 22:12:48 Starting - Launching requested ML instancesProfilerReport-1644271944: InProgress
# .........
# 2022-02-07 22:14:08 Starting - Preparing the instances for training...
# 2022-02-07 22:14:49 Downloading - Downloading input data.........
# 2022-02-07 22:16:13 Training - Downloading the training image.....Docker entrypoint called with argument(s): train
# [02/07/2022 22:17:08 INFO 140435680151360] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [02/07/2022 22:17:08 INFO 140435680151360] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'num_classes': '10', 'early_stopping_tolerance': '0.05', 'num_training_samples': '15696', 'use_pretrained_model': '1', 'precision_dtype': 'float16', 'early_stopping': 'True', 'num_layers': '18', 'epochs': '8', 'image_shape': '3,480,640', 'learning_rate': '0.01', 'mini_batch_size': '128'}
# [02/07/2022 22:17:08 INFO 140435680151360] Final configuration: {'use_pretrained_model': '1', 'num_layers': '18', 'epochs': '8', 'learning_rate': '0.01', 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': '128', 'image_shape': '3,480,640', 'precision_dtype': 'float16', 'num_classes': '10', 'early_stopping_tolerance': '0.05', 'num_training_samples': '15696', 'early_stopping': 'True'}
#
# 2022-02-07 22:17:13 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [02/07/2022 22:17:17 INFO 140687305029440] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [02/07/2022 22:17:17 INFO 140687305029440] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'num_classes': '10', 'early_stopping_tolerance': '0.05', 'num_training_samples': '15696', 'use_pretrained_model': '1', 'precision_dtype': 'float16', 'early_stopping': 'True', 'num_layers': '18', 'epochs': '8', 'image_shape': '3,480,640', 'learning_rate': '0.01', 'mini_batch_size': '128'}
# [02/07/2022 22:17:17 INFO 140687305029440] Final configuration: {'use_pretrained_model': '1', 'num_layers': '18', 'epochs': '8', 'learning_rate': '0.01', 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': '128', 'image_shape': '3,480,640', 'precision_dtype': 'float16', 'num_classes': '10', 'early_stopping_tolerance': '0.05', 'num_training_samples': '15696', 'early_stopping': 'True'}
# [02/07/2022 22:17:18 INFO 140687305029440] Launching parameter server for role scheduler
# [02/07/2022 22:17:18 INFO 140687305029440] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-164-201.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/574caf67-47eb-4402-842f-1696348e9020', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'ALGO_INPUT_DIR': '/opt/ml/input'}
# [02/07/2022 22:17:18 INFO 140687305029440] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-164-201.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/574caf67-47eb-4402-842f-1696348e9020', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'ALGO_INPUT_DIR': '/opt/ml/input', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.164.201', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [02/07/2022 22:17:18 INFO 140687305029440] Launching parameter server for role server
# [02/07/2022 22:17:18 INFO 140687305029440] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-164-201.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/574caf67-47eb-4402-842f-1696348e9020', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'ALGO_INPUT_DIR': '/opt/ml/input'}
# [02/07/2022 22:17:18 INFO 140687305029440] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-164-201.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/574caf67-47eb-4402-842f-1696348e9020', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'ALGO_INPUT_DIR': '/opt/ml/input', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.164.201', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [02/07/2022 22:17:18 INFO 140687305029440] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-164-201.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/574caf67-47eb-4402-842f-1696348e9020', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/3bc1a35f-ee8f-495b-b523-26d31ac63485', 'ALGO_INPUT_DIR': '/opt/ml/input', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.164.201', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [02/07/2022 22:17:18 INFO 140687305029440] Searching for .rec files in /opt/ml/input/data/train.
# [02/07/2022 22:17:18 INFO 140687305029440] Searching for .rec files in /opt/ml/input/data/validation.
# [02/07/2022 22:17:18 INFO 140687305029440] use_pretrained_model: 1
# [02/07/2022 22:17:18 INFO 140687305029440] multi_label: 0
# [02/07/2022 22:17:18 INFO 140687305029440] Using pretrained model for initializing weights and transfer learning.
# [02/07/2022 22:17:18 INFO 140687305029440] ---- Parameters ----
# [02/07/2022 22:17:18 INFO 140687305029440] num_layers: 18
# [02/07/2022 22:17:18 INFO 140687305029440] data type: <class 'numpy.float16'>
# [02/07/2022 22:17:18 INFO 140687305029440] epochs: 8
# [02/07/2022 22:17:18 INFO 140687305029440] optimizer: sgd
# [02/07/2022 22:17:18 INFO 140687305029440] momentum: 0.9
# [02/07/2022 22:17:18 INFO 140687305029440] weight_decay: 0.0001
# [02/07/2022 22:17:18 INFO 140687305029440] learning_rate: 0.01
# [02/07/2022 22:17:18 INFO 140687305029440] num_training_samples: 15696
# [02/07/2022 22:17:18 INFO 140687305029440] mini_batch_size: 128
# [02/07/2022 22:17:18 INFO 140687305029440] image_shape: 3,480,640
# [02/07/2022 22:17:18 INFO 140687305029440] num_classes: 10
# [02/07/2022 22:17:18 INFO 140687305029440] augmentation_type: None
# [02/07/2022 22:17:18 INFO 140687305029440] kv_store: dist_sync
# [02/07/2022 22:17:18 INFO 140687305029440] checkpoint_frequency not set, will store the best model
# [02/07/2022 22:17:18 INFO 140687305029440] Using early stopping for training
# [02/07/2022 22:17:18 INFO 140687305029440] Early stopping minimum epochs: 10
# [02/07/2022 22:17:18 INFO 140687305029440] Early stopping patience: 10
# [02/07/2022 22:17:18 INFO 140687305029440] Early stopping tolerance: 0.05
# [02/07/2022 22:17:18 INFO 140687305029440] --------------------
# [22:17:18] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_ecl_Cuda_10.1.x.10365.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [22:17:18] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_ecl_Cuda_10.1.x.10365.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [02/07/2022 22:17:18 INFO 140435680151360] Launching parameter server for role server
# [02/07/2022 22:17:18 INFO 140435680151360] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-134-232.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/28d577fe-39f3-459f-8f9d-cee7202bf897', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/72ece0d2-43e9-4a7f-98f5-25bbbabbecab', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/72ece0d2-43e9-4a7f-98f5-25bbbabbecab', 'ALGO_INPUT_DIR': '/opt/ml/input'}
# [02/07/2022 22:17:18 INFO 140435680151360] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-134-232.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/28d577fe-39f3-459f-8f9d-cee7202bf897', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/72ece0d2-43e9-4a7f-98f5-25bbbabbecab', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/72ece0d2-43e9-4a7f-98f5-25bbbabbecab', 'ALGO_INPUT_DIR': '/opt/ml/input', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.164.201', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [02/07/2022 22:17:18 INFO 140435680151360] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-134-232.eu-central-1.compute.internal', 'ALGO_OUTPUT_DIR': '/opt/ml/output', 'TRAINING_JOB_NAME': 'IC-Distraction-Driver-1644271944', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:957922590568:training-job/ic-distraction-driver-1644271944', 'ALGO_INPUT_DATA_DIR': '/opt/ml/input/data', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/28d577fe-39f3-459f-8f9d-cee7202bf897', 'IMAGE_CLASSIFICATION_PRETRAINED': '/pretrained', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility,compat32,graphics,video', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'ALGO_MODEL_DIR': '/opt/ml/model', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin', 'ALGO_INPUT_RESOURCE_CONFIG_FILE': '/opt/ml/input/config/resourceconfig.json', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'eu-central-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'ALGO_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'HOME': '/root', 'SHLVL': '1', 'KMP_AFFINITY': 'granularity=fine,compact,1,0', 'ALGO_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/72ece0d2-43e9-4a7f-98f5-25bbbabbecab', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/72ece0d2-43e9-4a7f-98f5-25bbbabbecab', 'ALGO_INPUT_DIR': '/opt/ml/input', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.164.201', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [02/07/2022 22:17:18 INFO 140435680151360] Searching for .rec files in /opt/ml/input/data/train.
# [02/07/2022 22:17:18 INFO 140435680151360] Searching for .rec files in /opt/ml/input/data/validation.
# [02/07/2022 22:17:18 INFO 140435680151360] use_pretrained_model: 1
# [02/07/2022 22:17:18 INFO 140435680151360] multi_label: 0
# [02/07/2022 22:17:18 INFO 140435680151360] Using pretrained model for initializing weights and transfer learning.
# [02/07/2022 22:17:18 INFO 140435680151360] ---- Parameters ----
# [02/07/2022 22:17:18 INFO 140435680151360] num_layers: 18
# [02/07/2022 22:17:18 INFO 140435680151360] data type: <class 'numpy.float16'>
# [02/07/2022 22:17:18 INFO 140435680151360] epochs: 8
# [02/07/2022 22:17:18 INFO 140435680151360] optimizer: sgd
# [02/07/2022 22:17:18 INFO 140435680151360] momentum: 0.9
# [02/07/2022 22:17:18 INFO 140435680151360] weight_decay: 0.0001
# [02/07/2022 22:17:18 INFO 140435680151360] learning_rate: 0.01
# [02/07/2022 22:17:18 INFO 140435680151360] num_training_samples: 15696
# [02/07/2022 22:17:18 INFO 140435680151360] mini_batch_size: 128
# [02/07/2022 22:17:18 INFO 140435680151360] image_shape: 3,480,640
# [02/07/2022 22:17:18 INFO 140435680151360] num_classes: 10
# [02/07/2022 22:17:18 INFO 140435680151360] augmentation_type: None
# [02/07/2022 22:17:18 INFO 140435680151360] kv_store: dist_sync
# [02/07/2022 22:17:18 INFO 140435680151360] checkpoint_frequency not set, will store the best model
# [02/07/2022 22:17:18 INFO 140435680151360] Using early stopping for training
# [02/07/2022 22:17:18 INFO 140435680151360] Early stopping minimum epochs: 10
# [02/07/2022 22:17:18 INFO 140435680151360] Early stopping patience: 10
# [02/07/2022 22:17:18 INFO 140435680151360] Early stopping tolerance: 0.05
# [02/07/2022 22:17:18 INFO 140435680151360] --------------------
# [22:17:18] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_ecl_Cuda_10.1.x.10365.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [22:17:18] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_ecl_Cuda_10.1.x.10365.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
#